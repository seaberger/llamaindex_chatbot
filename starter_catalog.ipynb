# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
from dotenv import load_dotenv
load_dotenv()

# Now you can access the environment variable
import os
openai_api_key = os.getenv('OPENAI_API_KEY')

# %%
import os.path
from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
)

# %%
# check if storage already exists
PERSIST_DIR = "./storage"
if not os.path.exists(PERSIST_DIR):
    # load the documents and create the index
    documents = SimpleDirectoryReader("catalog").load_data()
    index = VectorStoreIndex.from_documents(documents)
    # store it for later
    index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    # load the existing index
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
    index = load_index_from_storage(storage_context)
# Out:
# DEBUG:llama_index.core.readers.file.base:> [SimpleDirectoryReader] Total files added: 1
# > [SimpleDirectoryReader] Total files added: 1
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: LASER MEASUREMENT
# AND CONTROL
# Product Catalog
# > Adding chunk: LASER MEASUREMENT
# AND CONTROL
# Product Catalog
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk:
# > Adding chunk:
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Technical SupportOperational
# Excellence
# Custome...
# > Adding chunk: Technical SupportOperational
# Excellence
# Custome...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 2
# Superior Reliability & Performance           ...
# > Adding chunk: 2
# Superior Reliability & Performance           ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 3
# •                 Toll Free: (800) 343-4912  ...
# > Adding chunk: 3
# •                 Toll Free: (800) 343-4912  ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 4
# Superior Reliability & Performance           ...
# > Adding chunk: 4
# Superior Reliability & Performance           ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 5
# •                 Toll Free: (800) 343-4912  ...
# > Adding chunk: 5
# •                 Toll Free: (800) 343-4912  ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 6
# Superior Reliability & Performance           ...
# > Adding chunk: 6
# Superior Reliability & Performance           ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 7
# •                 Toll Free: (800) 343-4912  ...
# > Adding chunk: 7
# •                 Toll Free: (800) 343-4912  ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 8
# Superior Reliability & Performance           ...
# > Adding chunk: 8
# Superior Reliability & Performance           ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 9
# •                 Toll Free: (800) 343-4912  ...
# > Adding chunk: 9
# •                 Toll Free: (800) 343-4912  ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 10
# Superior Reliability & Performance          ...
# > Adding chunk: 10
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 11
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 11
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 12
# Superior Reliability & Performance          ...
# > Adding chunk: 12
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 13
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 13
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 14
# Superior Reliability & Performance          ...
# > Adding chunk: 14
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 15
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 15
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 16
# Superior Reliability & Performance          ...
# > Adding chunk: 16
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 17
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 17
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 18
# Superior Reliability & Performance          ...
# > Adding chunk: 18
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 19
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 19
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 20
# Superior Reliability & Performance          ...
# > Adding chunk: 20
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 21
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 21
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 22
# Superior Reliability & Performance          ...
# > Adding chunk: 22
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 23
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 23
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 24
# Superior Reliability & Performance          ...
# > Adding chunk: 24
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 25
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 25
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 26
# Superior Reliability & Performance          ...
# > Adding chunk: 26
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 27
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 27
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 28
# Superior Reliability & Performance          ...
# > Adding chunk: 28
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 29
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 29
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 30
# Superior Reliability & Performance          ...
# > Adding chunk: 30
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 31
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 31
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 32
# Superior Reliability & Performance          ...
# > Adding chunk: 32
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 33
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 33
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 34
# Superior Reliability & Performance          ...
# > Adding chunk: 34
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 35
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 35
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 36
# Superior Reliability & Performance          ...
# > Adding chunk: 36
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 37
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 37
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Mounting Hol e
# 2X 6-32 UNC-2B THD
#    6 mm (0.25...
# > Adding chunk: Mounting Hol e
# 2X 6-32 UNC-2B THD
#    6 mm (0.25...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 38
# Superior Reliability & Performance          ...
# > Adding chunk: 38
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 39
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 39
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Mounting Hol e
# 2X 6-32 UNC-2B THD
#    6 mm (0.25...
# > Adding chunk: Mounting Hol e
# 2X 6-32 UNC-2B THD
#    6 mm (0.25...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 40
# Superior Reliability & Performance          ...
# > Adding chunk: 40
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 41
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 41
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 42
# Superior Reliability & Performance          ...
# > Adding chunk: 42
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 43
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 43
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 44
# Superior Reliability & Performance          ...
# > Adding chunk: 44
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 45
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 45
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 46
# Superior Reliability & Performance          ...
# > Adding chunk: 46
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 47
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 47
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 48
# Superior Reliability & Performance          ...
# > Adding chunk: 48
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 49
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 49
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 50
# Superior Reliability & Performance          ...
# > Adding chunk: 50
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 51
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 51
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 52
# Superior Reliability & Performance          ...
# > Adding chunk: 52
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 53
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 53
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 15 to 1.0 10 mW 10 W 1 mW 0.5 to 10 19 UV – 514...
# > Adding chunk: 15 to 1.0 10 mW 10 W 1 mW 0.5 to 10 19 UV – 514...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 54
# Superior Reliability & Performance          ...
# > Adding chunk: 54
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 6 100 mW 200 W 10 mW 0.5 to 100 19 HTD 10600 5 ...
# > Adding chunk: 6 100 mW 200 W 10 mW 0.5 to 100 19 HTD 10600 5 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 55
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 55
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 56
# Superior Reliability & Performance          ...
# > Adding chunk: 56
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Light Tube
# PM3 only
# (removable)
# Ø63 mm
# (2.48 in...
# > Adding chunk: Light Tube
# PM3 only
# (removable)
# Ø63 mm
# (2.48 in...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 57
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 57
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 58
# Superior Reliability & Performance          ...
# > Adding chunk: 58
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 59
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 59
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 60
# Superior Reliability & Performance          ...
# > Adding chunk: 60
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 61
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 61
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 62
# Superior Reliability & Performance          ...
# > Adding chunk: 62
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 63
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 63
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 64
# Superior Reliability & Performance          ...
# > Adding chunk: 64
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: )89 mm
# (3.5 in.)Ø50 mm
# (1.97 in.) 31 mm
# (1.23 i...
# > Adding chunk: )89 mm
# (3.5 in.)Ø50 mm
# (1.97 in.) 31 mm
# (1.23 i...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 65
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 65
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 66
# Superior Reliability & Performance          ...
# > Adding chunk: 66
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 67
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 67
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 68
# Superior Reliability & Performance          ...
# > Adding chunk: 68
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 69
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 69
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 70
# Superior Reliability & Performance          ...
# > Adding chunk: 70
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 71
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 71
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 72
# Superior Reliability & Performance          ...
# > Adding chunk: 72
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 73
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 73
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 74
# Superior Reliability & Performance          ...
# > Adding chunk: 74
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 75
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 75
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 76
# Superior Reliability & Performance          ...
# > Adding chunk: 76
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 77
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 77
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 78
# Superior Reliability & Performance          ...
# > Adding chunk: 78
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 79
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 79
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 80
# Superior Reliability & Performance          ...
# > Adding chunk: 80
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 81
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 81
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 82
# Superior Reliability & Performance          ...
# > Adding chunk: 82
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 83
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 83
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 84
# Superior Reliability & Performance          ...
# > Adding chunk: 84
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 85
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 85
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 86
# Superior Reliability & Performance          ...
# > Adding chunk: 86
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 87
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 87
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 88
# Superior Reliability & Performance          ...
# > Adding chunk: 88
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 89
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 89
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 90
# Superior Reliability & Performance          ...
# > Adding chunk: 90
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 91
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 91
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 92
# Superior Reliability & Performance          ...
# > Adding chunk: 92
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 93
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 93
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 94
# Superior Reliability & Performance          ...
# > Adding chunk: 94
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 95
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 95
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 96
# Superior Reliability & Performance          ...
# > Adding chunk: 96
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 97
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 97
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 98
# Superior Reliability & Performance          ...
# > Adding chunk: 98
# Superior Reliability & Performance          ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 99
# •                 Toll Free: (800) 343-4912 ...
# > Adding chunk: 99
# •                 Toll Free: (800) 343-4912 ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 2 50 mm EnergyMax sensors are compatible with t...
# > Adding chunk: 2 50 mm EnergyMax sensors are compatible with t...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 100
# Superior Reliability & Performance         ...
# > Adding chunk: 100
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 101
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 101
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 102
# Superior Reliability & Performance         ...
# > Adding chunk: 102
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 103
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 103
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 104
# Superior Reliability & Performance         ...
# > Adding chunk: 104
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: and
# No. 1/4-20
# UNC-2B THD
# X    6.10 mm
# (0.24...
# > Adding chunk: and
# No. 1/4-20
# UNC-2B THD
# X    6.10 mm
# (0.24...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 105
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 105
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Max.
# 107.44 mm
# (4.23 in.) Min.Aperture
# PlateØ...
# > Adding chunk: Max.
# 107.44 mm
# (4.23 in.) Min.Aperture
# PlateØ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 106
# Superior Reliability & Performance         ...
# > Adding chunk: 106
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: for
# Mounting Sensor
# Note: Detector Surface
# is...
# > Adding chunk: for
# Mounting Sensor
# Note: Detector Surface
# is...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 107
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 107
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: M6-6H THD
# X    5.08 mm
# (0.20 in.) and
# No. 1/...
# > Adding chunk: M6-6H THD
# X    5.08 mm
# (0.20 in.) and
# No. 1/...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 108
# Superior Reliability & Performance         ...
# > Adding chunk: 108
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 109
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 109
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 110
# Superior Reliability & Performance         ...
# > Adding chunk: 110
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 111
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 111
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 112
# Superior Reliability & Performance         ...
# > Adding chunk: 112
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Adjustabl e
# 200.15 mm (7.88 in.) Max.
# 117.60 mm...
# > Adding chunk: Adjustabl e
# 200.15 mm (7.88 in.) Max.
# 117.60 mm...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 113
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 113
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: PC Application Software included.
# • Optional he...
# > Adding chunk: PC Application Software included.
# • Optional he...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 114
# Superior Reliability & Performance         ...
# > Adding chunk: 114
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 115
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 115
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 116
# Superior Reliability & Performance         ...
# > Adding chunk: 116
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 117
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 117
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 118
# Superior Reliability & Performance         ...
# > Adding chunk: 118
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 119
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 119
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 120
# Superior Reliability & Performance         ...
# > Adding chunk: 120
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 121
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 121
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 122
# Superior Reliability & Performance         ...
# > Adding chunk: 122
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 123
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 123
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 124
# Superior Reliability & Performance         ...
# > Adding chunk: 124
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: )Ø 22.0 mm (0.87 in.)
# Cap Not Shown
# 45.2 mm
# (1....
# > Adding chunk: )Ø 22.0 mm (0.87 in.)
# Cap Not Shown
# 45.2 mm
# (1....
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: standard A/B cable included
# Trigger  Connector ...
# > Adding chunk: standard A/B cable included
# Trigger  Connector ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 125
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 125
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 126
# Superior Reliability & Performance         ...
# > Adding chunk: 126
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 127
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 127
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 128
# Superior Reliability & Performance         ...
# > Adding chunk: 128
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 129
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 129
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 130
# Superior Reliability & Performance         ...
# > Adding chunk: 130
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 131
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 131
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 132
# Superior Reliability & Performance         ...
# > Adding chunk: 132
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 133
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 133
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Power Density (W/cm2) 1* 1* 1* 2.0 x 10 9 2.0 x...
# > Adding chunk: Power Density (W/cm2) 1* 1* 1* 2.0 x 10 9 2.0 x...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 134
# Superior Reliability & Performance         ...
# > Adding chunk: 134
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 135
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 135
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 136
# Superior Reliability & Performance         ...
# > Adding chunk: 136
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 137
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 137
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 138
# Superior Reliability & Performance         ...
# > Adding chunk: 138
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 139
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 139
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 140
# Superior Reliability & Performance         ...
# > Adding chunk: 140
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 141
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 141
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 142
# Superior Reliability & Performance         ...
# > Adding chunk: 142
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 142
# Superior Reliability & Performance         ...
# > Adding chunk: 142
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 143
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 143
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 144
# Superior Reliability & Performance         ...
# > Adding chunk: 144
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 145
# •                 Toll Free: (800) 343-4912...
# > Adding chunk: 145
# •                 Toll Free: (800) 343-4912...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 146
# Superior Reliability & Performance         ...
# > Adding chunk: 146
# Superior Reliability & Performance         ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: How to Contact Us
# 147Contact Us by Phone
#
# Cohe...
# > Adding chunk: How to Contact Us
# 147Contact Us by Phone
#
# Cohe...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: All Coherent product names are trademarks of Co...
# > Adding chunk: All Coherent product names are trademarks of Co...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: •                 Toll Free: (800) 343-4912    ...
# > Adding chunk: •                 Toll Free: (800) 343-4912    ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: MC-002-15-0M0821Rev.A  Copyright ©2021 Coherent...
# > Adding chunk: MC-002-15-0M0821Rev.A  Copyright ©2021 Coherent...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x7f6b0c8f3e20>, 'json_data': {'input': ['page_label: 1 file_path: catalog/laser-measurement-and-control-cat.pdf  LASER MEASUREMENT   AND CONTROL Product Catalog', 'page_label: 2 file_path: catalog/laser-measurement-and-control-cat.pdf', 'page_label: 3 file_path: catalog/laser-measurement-and-control-cat.pdf  Technical SupportOperational Excellence Customer Service SuperiorWarrantyOn-Time Delivery 1 Day Ship Program Product ReliabilityOperational Excellence For over 40 years, Coherent has been supplying you   with the best laser measurement and beam diagnostic   equipment available. We realize that while technical   specifications greatly influence your purchasing   decisions, you also must consider many other   important criteria. Through customer surveys   we found that Product Reliability, Speed of   Responsiveness, and Technical Support   are the three top criteria when choosing   a laser test and measurement supplier.   That’s why we place as much emphasis   on Operational Excellence as we do   on technical superiority. Operational   Excellence means: • Overall product warranty rate <1% • Calibration turnaround time <5 days • On-time delivery for all new orders >95% • Shipment of 1 Day Ship Program orders    within 24 hours For Product Reliability, Speed of Responsiveness,   and Technical Support, make the safe choice you can   always count on Coherent.Operational Experience You Can Count On Coherent 1 Day Ship Program Items in the catalog with the             icon next to the part number are in our 1 Day Ship Program.  Orders that exclusively contain 1 Day Ship items are eligible for next business day shipment from the  manufacturing site in Wilsonville, Oregon.      •                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-4042                 •                 Fax: (503) 454-5727 1', 'page_label: 4 file_path: catalog/laser-measurement-and-control-cat.pdf  2 Superior Reliability & Performance                 •                 www.coherent.com                 •                 LMC.sales@coherent.comTable of ContentsLaser Measurement and Control Power & Energy Power & Energy Meters PowerMax-Pro Sensors Power Sensors Energy SensorsNew Products New Products 4 Introduction Power and Energy Measurement Solutions 5-7 Power and Energy Meters Power and Energy Meter Quick Reference Guide 8 Compatibility Chart for Our Most Popular Meters and Sensors 9 LabMax-Pro SSIM 10-13 LabMax-Pro Mobile App 14-15 LabMax Meters 16-18 FieldMaxII Meters 19-20 FieldMate 21 LaserCheck 22 LMC System Kits and Meter Accessories 23   Power Sensors PowerMax-Pro Sensors Introduction 24-27 PowerMax-Pro - FAST Laser Power Sensors 28-48 PowerMax Sensors Introduction 49-54 PowerMax - Laser Power Sensors 55-88  Custom and OEM Products Introduction 89  OEM Thermopiles (10 mW to 1 kW) 90-91  OEM Thermopile Detailed Drawings 92 PowerMax Sensor Accessories 93-95 EnergyMax Sensors Introduction 96-103 EnergyMax - Laser Energy Sensors 104-117 EnergyMax Sensor Accessories 118-119 Measuring Energy with an Oscilloscope 120 J100 Energy Sensor 121', 'page_label: 5 file_path: catalog/laser-measurement-and-control-cat.pdf  3 •                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-4042                 •                 Fax: (503) 454-5727Beam Diagnostics Introduction to Laser Beam Diagnostics 122-123 Beam Diagnostic Cameras LaserCam-HR II  124 LaserCam-HR II UV 124 LaserCam-HR-InGaAs 125 BeamView-USB Analyzer Software BeamView-USB 126-131 Beam Diagnostic Accessories Laser Grade Attenuation Optics for Cameras 132 Attenuation Optics for Cameras 133 Extreme-UV Beam Intensity Profile Optics 134 BeamMaster Knife-Edge Based Beam Profilers 135-136 BeamMaster Accessories 137 ISO 17025, Calibration, Warranty and Service  138-139 Measurement Products for  ...
# Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x7f6b0c8f3e20>, 'json_data': {'input': ['page_label: 1 file_path: catalog/laser-measurement-and-control-cat.pdf  LASER MEASUREMENT   AND CONTROL Product Catalog', 'page_label: 2 file_path: catalog/laser-measurement-and-control-cat.pdf', 'page_label: 3 file_path: catalog/laser-measurement-and-control-cat.pdf  Technical SupportOperational Excellence Customer Service SuperiorWarrantyOn-Time Delivery 1 Day Ship Program Product ReliabilityOperational Excellence For over 40 years, Coherent has been supplying you   with the best laser measurement and beam diagnostic   equipment available. We realize that while technical   specifications greatly influence your purchasing   decisions, you also must consider many other   important criteria. Through customer surveys   we found that Product Reliability, Speed of   Responsiveness, and Technical Support   are the three top criteria when choosing   a laser test and measurement supplier.   That’s why we place as much emphasis   on Operational Excellence as we do   on technical superiority. Operational   Excellence means: • Overall product warranty rate <1% • Calibration turnaround time <5 days • On-time delivery for all new orders >95% • Shipment of 1 Day Ship Program orders    within 24 hours For Product Reliability, Speed of Responsiveness,   and Technical Support, make the safe choice you can   always count on Coherent.Operational Experience You Can Count On Coherent 1 Day Ship Program Items in the catalog with the             icon next to the part number are in our 1 Day Ship Program.  Orders that exclusively contain 1 Day Ship items are eligible for next business day shipment from the  manufacturing site in Wilsonville, Oregon.      •                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-4042                 •                 Fax: (503) 454-5727 1', 'page_label: 4 file_path: catalog/laser-measurement-and-control-cat.pdf  2 Superior Reliability & Performance                 •                 www.coherent.com                 •                 LMC.sales@coherent.comTable of ContentsLaser Measurement and Control Power & Energy Power & Energy Meters PowerMax-Pro Sensors Power Sensors Energy SensorsNew Products New Products 4 Introduction Power and Energy Measurement Solutions 5-7 Power and Energy Meters Power and Energy Meter Quick Reference Guide 8 Compatibility Chart for Our Most Popular Meters and Sensors 9 LabMax-Pro SSIM 10-13 LabMax-Pro Mobile App 14-15 LabMax Meters 16-18 FieldMaxII Meters 19-20 FieldMate 21 LaserCheck 22 LMC System Kits and Meter Accessories 23   Power Sensors PowerMax-Pro Sensors Introduction 24-27 PowerMax-Pro - FAST Laser Power Sensors 28-48 PowerMax Sensors Introduction 49-54 PowerMax - Laser Power Sensors 55-88  Custom and OEM Products Introduction 89  OEM Thermopiles (10 mW to 1 kW) 90-91  OEM Thermopile Detailed Drawings 92 PowerMax Sensor Accessories 93-95 EnergyMax Sensors Introduction 96-103 EnergyMax - Laser Energy Sensors 104-117 EnergyMax Sensor Accessories 118-119 Measuring Energy with an Oscilloscope 120 J100 Energy Sensor 121', 'page_label: 5 file_path: catalog/laser-measurement-and-control-cat.pdf  3 •                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-4042                 •                 Fax: (503) 454-5727Beam Diagnostics Introduction to Laser Beam Diagnostics 122-123 Beam Diagnostic Cameras LaserCam-HR II  124 LaserCam-HR II UV 124 LaserCam-HR-InGaAs 125 BeamView-USB Analyzer Software BeamView-USB 126-131 Beam Diagnostic Accessories Laser Grade Attenuation Optics for Cameras 132 Attenuation Optics for Cameras 133 Extreme-UV Beam Intensity Profile Optics 134 BeamMaster Knife-Edge Based Beam Profilers 135-136 BeamMaster Accessories 137 ISO 17025, Calibration, Warranty and Service  138-139 Measurement Products for Use with Coherent Lasers   ...
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0a94f6d0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0a94f6d0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7f6b0d798e40> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x7f6b0d798e40> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0b251600>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0b251600>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Feb 2024 22:44:10 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-model', b'text-embedding-ada-002'), (b'openai-organization', b'user-qh4ik9sb9vucjsc5yoawi3rh'), (b'openai-processing-ms', b'267'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'948684'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'3.078s'), (b'x-request-id', b'req_a7d8de636f459d0cfd6fd4d1ebdebe38'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'85718da9bda8c4c5-SEA'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Feb 2024 22:44:10 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-model', b'text-embedding-ada-002'), (b'openai-organization', b'user-qh4ik9sb9vucjsc5yoawi3rh'), (b'openai-processing-ms', b'267'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'948684'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'3.078s'), (b'x-request-id', b'req_a7d8de636f459d0cfd6fd4d1ebdebe38'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'85718da9bda8c4c5-SEA'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x7f6b0c8f3e20>, 'json_data': {'input': ['page_label: 95 file_path: catalog/laser-measurement-and-control-cat.pdf  93 •                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-4042                 •                 Fax: (503) 454-5727The following fiber-optic adapters can be mounted directly onto the 3/4-32 threads on  the front of LM-3 and LM-10 sensors. These fiber adapters can also be used with our  1.035-40M adapter ring to fit on the LM-45, LM-20, and LM-200 sensors. The following fiber adapters can be mounted onto the front of the PS10 sensor   in place of the removable light tube. Part Number Description Sensors 0012-3860 PS-SMA-Type Connector PS10 0012-3863 PS-FC-Type Connector PS10Part Number Description Sensors 1098589 SMA-Type Connector LM-3, LM-10 1098339 FC/PC-Type Connector LM-3, LM-10 33-9432-000 1.035-40M Adapter Ring LM-45, LM-20, LM-100, LM-200Fiber-Optic Connector AdaptersPowerMax Sensor Accessories Part Number Description 1105557 5V External Power SupplyPowerMax-RS Sensor Power SupplySMA and FC Adapters SMA and FC Adapters Part Number Description 1211488 Collimating Adapter 1211489 FC Fiber Adapter 1220619 FC-APC Fiber Adapter 1220621 SMA Fiber Adapter 1220622 7 mm AperturePowerMax-USB Wand UV/VIS Adapters Power Sensors', 'page_label: 96 file_path: catalog/laser-measurement-and-control-cat.pdf  94 Superior Reliability & Performance                 •                 www.coherent.com                 •                 LMC.sales@coherent.comThe Thermal SmartSensor Adapter converts LM-model position-sensing  thermopiles and LM-2 optical sensors for use with FieldMaxII and   FieldMate meters. Designed for use with multiple sensors, this adapter can read the sensor  EEPROM contents and program itself when powered up via the meter  connection.  Note: Beam position information is not available when using these meters. This attenuator is used with OP-2 VIS, LM-2 VIS, OP-2 IR and LM-2 IR sensors  to allow operation up to 5W in the visible and 3W in the infrared regions. The  attenuator threads into the sensor in place of the light shield to provide from  1100:1 to 950:1 attenuation. Each attenuator is calibrated for 1000:1 ±5% at  635 nm and is supplied with a calibration certificate. The useful spectral range  is 400 to 1800 nm. The clear input aperture is 0.312” (7.9 mm) in diameter. Thermal SmartSensor AdapterPowerMax Sensor Accessories Part Number Description 1056827 ** Thermal SmartSensor Adapter Part Number Description 1098318 ** 1000:1 Attenuator for OP-2 and LM-2 Sensors1000:1 AttenuatorThermal SmartSensor Adapter 1000:1 Attenuator 400 Wavelength (nm) Attenuation Ration800:1900:11000:11100:1 600 800 1000 1200 1400 1600 1800Calibrated @ 1000:1 ±5% @ 635 mmCalibrated @ 1000:1 ±5% @ 635 mmCalibrated @ 1000:1 ±5% @ 635 mm Ø8 mm (0.31 in.) Ø44 mm (1.75 in.)Ø22 mm (0.88 in.)Ø3 mm (0.12 in.) 5 mm (0.19 in.)3/4-32 UN-2A 51 mm (2.02 in.)** 1 Day Ship program: eligible for next business day shipment. ** 1 Day Ship program: eligible for next business day shipment.**** Power Sensors', 'page_label: 97 file_path: catalog/laser-measurement-and-control-cat.pdf  95 •                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-4042                 •                 Fax: (503) 454-5727The following fiber-optic adapters can be mounted directly onto the   3/4-32 threads on the front of  LM-2, OP-2, LM-3, LM-10, and LM-150FS  sensors. These fiber adapters can also be used with our 1.035-40M adapter  ring to fit on the LM-20, LM-45, LM-100, LM-150 LS, and LM-200 sensors. The following fiber adapters can be mounted onto the front of the PS10 sensor  in place of the removable light tube. Fiber-Optic Connector AdaptersPowerMax Sensor Accessories SMA and FC Adapters SMA and FC AdaptersPart Number Description Senso ...
# Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x7f6b0c8f3e20>, 'json_data': {'input': ['page_label: 95 file_path: catalog/laser-measurement-and-control-cat.pdf  93 •                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-4042                 •                 Fax: (503) 454-5727The following fiber-optic adapters can be mounted directly onto the 3/4-32 threads on  the front of LM-3 and LM-10 sensors. These fiber adapters can also be used with our  1.035-40M adapter ring to fit on the LM-45, LM-20, and LM-200 sensors. The following fiber adapters can be mounted onto the front of the PS10 sensor   in place of the removable light tube. Part Number Description Sensors 0012-3860 PS-SMA-Type Connector PS10 0012-3863 PS-FC-Type Connector PS10Part Number Description Sensors 1098589 SMA-Type Connector LM-3, LM-10 1098339 FC/PC-Type Connector LM-3, LM-10 33-9432-000 1.035-40M Adapter Ring LM-45, LM-20, LM-100, LM-200Fiber-Optic Connector AdaptersPowerMax Sensor Accessories Part Number Description 1105557 5V External Power SupplyPowerMax-RS Sensor Power SupplySMA and FC Adapters SMA and FC Adapters Part Number Description 1211488 Collimating Adapter 1211489 FC Fiber Adapter 1220619 FC-APC Fiber Adapter 1220621 SMA Fiber Adapter 1220622 7 mm AperturePowerMax-USB Wand UV/VIS Adapters Power Sensors', 'page_label: 96 file_path: catalog/laser-measurement-and-control-cat.pdf  94 Superior Reliability & Performance                 •                 www.coherent.com                 •                 LMC.sales@coherent.comThe Thermal SmartSensor Adapter converts LM-model position-sensing  thermopiles and LM-2 optical sensors for use with FieldMaxII and   FieldMate meters. Designed for use with multiple sensors, this adapter can read the sensor  EEPROM contents and program itself when powered up via the meter  connection.  Note: Beam position information is not available when using these meters. This attenuator is used with OP-2 VIS, LM-2 VIS, OP-2 IR and LM-2 IR sensors  to allow operation up to 5W in the visible and 3W in the infrared regions. The  attenuator threads into the sensor in place of the light shield to provide from  1100:1 to 950:1 attenuation. Each attenuator is calibrated for 1000:1 ±5% at  635 nm and is supplied with a calibration certificate. The useful spectral range  is 400 to 1800 nm. The clear input aperture is 0.312” (7.9 mm) in diameter. Thermal SmartSensor AdapterPowerMax Sensor Accessories Part Number Description 1056827 ** Thermal SmartSensor Adapter Part Number Description 1098318 ** 1000:1 Attenuator for OP-2 and LM-2 Sensors1000:1 AttenuatorThermal SmartSensor Adapter 1000:1 Attenuator 400 Wavelength (nm) Attenuation Ration800:1900:11000:11100:1 600 800 1000 1200 1400 1600 1800Calibrated @ 1000:1 ±5% @ 635 mmCalibrated @ 1000:1 ±5% @ 635 mmCalibrated @ 1000:1 ±5% @ 635 mm Ø8 mm (0.31 in.) Ø44 mm (1.75 in.)Ø22 mm (0.88 in.)Ø3 mm (0.12 in.) 5 mm (0.19 in.)3/4-32 UN-2A 51 mm (2.02 in.)** 1 Day Ship program: eligible for next business day shipment. ** 1 Day Ship program: eligible for next business day shipment.**** Power Sensors', 'page_label: 97 file_path: catalog/laser-measurement-and-control-cat.pdf  95 •                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-4042                 •                 Fax: (503) 454-5727The following fiber-optic adapters can be mounted directly onto the   3/4-32 threads on the front of  LM-2, OP-2, LM-3, LM-10, and LM-150FS  sensors. These fiber adapters can also be used with our 1.035-40M adapter  ring to fit on the LM-20, LM-45, LM-100, LM-150 LS, and LM-200 sensors. The following fiber adapters can be mounted onto the front of the PS10 sensor  in place of the removable light tube. Fiber-Optic Connector AdaptersPowerMax Sensor Accessories SMA and FC Adapters SMA and FC AdaptersPart Number Description Sensors 1098589 SMA-Type Connec ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Feb 2024 22:44:11 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-model', b'text-embedding-ada-002'), (b'openai-organization', b'user-qh4ik9sb9vucjsc5yoawi3rh'), (b'openai-processing-ms', b'194'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'931092'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'4.134s'), (b'x-request-id', b'req_84d0f987907eeae19252fed5cee485c1'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'85718db06ebcc4c5-SEA'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Feb 2024 22:44:11 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-model', b'text-embedding-ada-002'), (b'openai-organization', b'user-qh4ik9sb9vucjsc5yoawi3rh'), (b'openai-processing-ms', b'194'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'931092'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'4.134s'), (b'x-request-id', b'req_84d0f987907eeae19252fed5cee485c1'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'85718db06ebcc4c5-SEA'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:fsspec.local:open file: /home/seanb/git/llamaindex_chatbot/storage/docstore.json
# open file: /home/seanb/git/llamaindex_chatbot/storage/docstore.json
# DEBUG:fsspec.local:open file: /home/seanb/git/llamaindex_chatbot/storage/index_store.json
# open file: /home/seanb/git/llamaindex_chatbot/storage/index_store.json
# DEBUG:fsspec.local:open file: /home/seanb/git/llamaindex_chatbot/storage/graph_store.json
# open file: /home/seanb/git/llamaindex_chatbot/storage/graph_store.json
# DEBUG:fsspec.local:open file: /home/seanb/git/llamaindex_chatbot/storage/default__vector_store.json
# open file: /home/seanb/git/llamaindex_chatbot/storage/default__vector_store.json
# DEBUG:fsspec.local:open file: /home/seanb/git/llamaindex_chatbot/storage/image__vector_store.json
# open file: /home/seanb/git/llamaindex_chatbot/storage/image__vector_store.json

# %%
query_engine = index.as_query_engine()
response = query_engine.query("What types of beam diagnostics systems does Coherent offer?")
print(response)
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x7f6b0b269cf0>, 'json_data': {'input': ['What types of beam diagnostics systems does Coherent offer?'], 'model': <OpenAIEmbeddingModeModel.TEXT_EMBED_ADA_002: 'text-embedding-ada-002'>, 'encoding_format': 'base64'}}
# Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x7f6b0b269cf0>, 'json_data': {'input': ['What types of beam diagnostics systems does Coherent offer?'], 'model': <OpenAIEmbeddingModeModel.TEXT_EMBED_ADA_002: 'text-embedding-ada-002'>, 'encoding_format': 'base64'}}
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0b2801f0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0b2801f0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7f6b0d798e40> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x7f6b0d798e40> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0e79fd60>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0e79fd60>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Feb 2024 22:45:03 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-model', b'text-embedding-ada-002'), (b'openai-organization', b'user-qh4ik9sb9vucjsc5yoawi3rh'), (b'openai-processing-ms', b'16'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'999986'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_dd728cde7a1ebfc1c42056ede385db07'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'85718ef94eb32819-SEA'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Feb 2024 22:45:03 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-model', b'text-embedding-ada-002'), (b'openai-organization', b'user-qh4ik9sb9vucjsc5yoawi3rh'), (b'openai-processing-ms', b'16'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'999986'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_dd728cde7a1ebfc1c42056ede385db07'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'85718ef94eb32819-SEA'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:llama_index.core.indices.utils:> Top 2 nodes:
# > [Node e25a644f-5c97-4080-9254-357834357162] [Similarity score:             0.852099] 123
# •                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-...
# > [Node f6930ae0-2077-4a89-abff-c6b45a35024a] [Similarity score:             0.839632] 122
# Superior Reliability & Performance                 •                 www.coherent.com        ...
# > Top 2 nodes:
# > [Node e25a644f-5c97-4080-9254-357834357162] [Similarity score:             0.852099] 123
# •                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-...
# > [Node f6930ae0-2077-4a89-abff-c6b45a35024a] [Similarity score:             0.839632] 122
# Superior Reliability & Performance                 •                 www.coherent.com        ...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an expert Q&A system that is trusted around the world.\nAlways answer the query using the provided context information, and not prior knowledge.\nSome rules to follow:\n1. Never directly reference the given context in your answer.\n2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines."}, {'role': 'user', 'content': 'Context information is below.\n---------------------\npage_label: 125\nfile_path: catalog/laser-measurement-and-control-cat.pdf\n\n123\n•                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-4042                 •                 Fax: (503) 454-5727Introduction to Camera-Based Beam DiagnosticsLaserCam-HR II\nCoherent BeamView Analyzer systems \nare the recognized leader in software, \nhardware and optical components \nfor laser beam analysis. Constant \nproduct improvement based on cus-\ntomer feedback, and innovation from \nbeam analysis experts, have made \nBeamView Analyzer products the first \nchoice for laboratory, factory and field \nmeasurements.\nThe key elements of a typical camera-\nbased beam profiling system are the \ncamera itself, Coherent Beamview \nanalysis software running on an \nappropriate computer and, when \nnecessary, beam attenuation optics. \nThe key choice to make is matching \nthe appropriate camera technology to \nyour application.\nCoherent beam diagnostic cameras \nare specifically designed or modified \nfor laser analysis. They provide low noise, maximum linearity, and \nuniformity of response—needed for maximum measurement \naccuracy. All of these diagnostic cameras accept C-Mount optical \naccessories and are delivered without a cover (glass/plastic win-\ndow) over the sensor array. Instead, a LDFP (Low-Distortion Face \nPlate) filter is supplied with each camera—a laser-grade neutral \ndensity filter made of glass specified and polished specifically for \nlaser diagnostic analysis. The LDFP filter is mounted in a stan-\ndard C-Mount ring and provides attenuation of ambient room \nlight so that the camera can be used with normal room lights.\nUSB 2.0 Beam Diagnostic Camera Family  \nCoherent pioneered the ease-of-use of digital USB 2.0 bus-pow-\nered, high-resolution, large area cameras requiring only a single \ncable for both video transfer and camera power. The LaserCam-\nHR family of beam diagnostic cameras includes the LaserCam-HR \nII CCD cameras, the LaserCam-HR-UV and the LaserCam-HR-\nInGaAs models, covering the measurement spectrum from the \ndeep ultraviolet to the near-infrared wavelengths.\nWith a broad spectral range covering 190 nm to 1700 nm, there \nis a LaserCam-HR camera profiler system ideally suited for nearly \nany demanding laser measurement application including scien-\ntific, excimer lasers, telecommunications sources, and military \nlaser systems.\nImportant Considerations  \n• Ease-of-use connectivity\n  • High-speed USB 2.0 Interface\n  • USB bus-powered low voltage operation• Broad spectral range\n  • LaserCam-HR II 190 nm to 1100 nm \n    (400 to 1100 nm with LDFP) \n    (190 to 355 nm with BIP-12F)\n  • LaserCam-HR II-UV DUV to 355 nm\n  • LaserCam-HR-InGaAs 900 nm to 1700 nm\n• Large dynamic range\n• Digital output  through USB 2.0 eliminates the need for  \n an interface card (frame-grabber)\n• High-accuracy beam diameter calculations\n• Excellent beam spatial uniformity\n• Variable camera exposure time\n• High-speed image capture rates  \n (15 to 25 frames per second)\n• Pass/Fail TTL level output\n• RS-232 and TCP/IP communication protocols\n• All LaserCam-HR camera systems are RoHS  \n compliant\n• Cameras ship with BeamView diagnostics software  \n• Windows 7 & 10 (32-bit and 64-bit) compatible\nMultiple channel camera support of different LaserCam-HR cam-\nera models is available ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an expert Q&A system that is trusted around the world.\nAlways answer the query using the provided context information, and not prior knowledge.\nSome rules to follow:\n1. Never directly reference the given context in your answer.\n2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines."}, {'role': 'user', 'content': 'Context information is below.\n---------------------\npage_label: 125\nfile_path: catalog/laser-measurement-and-control-cat.pdf\n\n123\n•                 Toll Free: (800) 343-4912                 •                 Tel: (408) 764-4042                 •                 Fax: (503) 454-5727Introduction to Camera-Based Beam DiagnosticsLaserCam-HR II\nCoherent BeamView Analyzer systems \nare the recognized leader in software, \nhardware and optical components \nfor laser beam analysis. Constant \nproduct improvement based on cus-\ntomer feedback, and innovation from \nbeam analysis experts, have made \nBeamView Analyzer products the first \nchoice for laboratory, factory and field \nmeasurements.\nThe key elements of a typical camera-\nbased beam profiling system are the \ncamera itself, Coherent Beamview \nanalysis software running on an \nappropriate computer and, when \nnecessary, beam attenuation optics. \nThe key choice to make is matching \nthe appropriate camera technology to \nyour application.\nCoherent beam diagnostic cameras \nare specifically designed or modified \nfor laser analysis. They provide low noise, maximum linearity, and \nuniformity of response—needed for maximum measurement \naccuracy. All of these diagnostic cameras accept C-Mount optical \naccessories and are delivered without a cover (glass/plastic win-\ndow) over the sensor array. Instead, a LDFP (Low-Distortion Face \nPlate) filter is supplied with each camera—a laser-grade neutral \ndensity filter made of glass specified and polished specifically for \nlaser diagnostic analysis. The LDFP filter is mounted in a stan-\ndard C-Mount ring and provides attenuation of ambient room \nlight so that the camera can be used with normal room lights.\nUSB 2.0 Beam Diagnostic Camera Family  \nCoherent pioneered the ease-of-use of digital USB 2.0 bus-pow-\nered, high-resolution, large area cameras requiring only a single \ncable for both video transfer and camera power. The LaserCam-\nHR family of beam diagnostic cameras includes the LaserCam-HR \nII CCD cameras, the LaserCam-HR-UV and the LaserCam-HR-\nInGaAs models, covering the measurement spectrum from the \ndeep ultraviolet to the near-infrared wavelengths.\nWith a broad spectral range covering 190 nm to 1700 nm, there \nis a LaserCam-HR camera profiler system ideally suited for nearly \nany demanding laser measurement application including scien-\ntific, excimer lasers, telecommunications sources, and military \nlaser systems.\nImportant Considerations  \n• Ease-of-use connectivity\n  • High-speed USB 2.0 Interface\n  • USB bus-powered low voltage operation• Broad spectral range\n  • LaserCam-HR II 190 nm to 1100 nm \n    (400 to 1100 nm with LDFP) \n    (190 to 355 nm with BIP-12F)\n  • LaserCam-HR II-UV DUV to 355 nm\n  • LaserCam-HR-InGaAs 900 nm to 1700 nm\n• Large dynamic range\n• Digital output  through USB 2.0 eliminates the need for  \n an interface card (frame-grabber)\n• High-accuracy beam diameter calculations\n• Excellent beam spatial uniformity\n• Variable camera exposure time\n• High-speed image capture rates  \n (15 to 25 frames per second)\n• Pass/Fail TTL level output\n• RS-232 and TCP/IP communication protocols\n• All LaserCam-HR camera systems are RoHS  \n compliant\n• Cameras ship with BeamView diagnostics software  \n• Windows 7 & 10 (32-bit and 64-bit) compatible\nMultiple channel camera support of different LaserCam-HR cam-\nera models is available for all three LaserCam-HR ...
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0b0c2080>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0b0c2080>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7f6b0b254340> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x7f6b0b254340> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0b0c22c0>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f6b0b0c22c0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Feb 2024 22:45:05 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'Cache-Control', b'no-cache, must-revalidate'), (b'openai-model', b'gpt-3.5-turbo-0125'), (b'openai-organization', b'user-qh4ik9sb9vucjsc5yoawi3rh'), (b'openai-processing-ms', b'695'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'3500'), (b'x-ratelimit-limit-tokens', b'90000'), (b'x-ratelimit-remaining-requests', b'3499'), (b'x-ratelimit-remaining-tokens', b'88363'), (b'x-ratelimit-reset-requests', b'17ms'), (b'x-ratelimit-reset-tokens', b'1.091s'), (b'x-request-id', b'req_810875b5a580ed630e95e25b84bef285'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'85718efbaba96828-SEA'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 17 Feb 2024 22:45:05 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'Cache-Control', b'no-cache, must-revalidate'), (b'openai-model', b'gpt-3.5-turbo-0125'), (b'openai-organization', b'user-qh4ik9sb9vucjsc5yoawi3rh'), (b'openai-processing-ms', b'695'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'3500'), (b'x-ratelimit-limit-tokens', b'90000'), (b'x-ratelimit-remaining-requests', b'3499'), (b'x-ratelimit-remaining-tokens', b'88363'), (b'x-ratelimit-reset-requests', b'17ms'), (b'x-ratelimit-reset-tokens', b'1.091s'), (b'x-request-id', b'req_810875b5a580ed630e95e25b84bef285'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'85718efbaba96828-SEA'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# Coherent offers camera-based beam diagnostic systems and advanced knife-edge systems for beam diagnostics.
